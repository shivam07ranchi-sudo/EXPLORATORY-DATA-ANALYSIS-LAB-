# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam07ranchi-sudo/EXPLORATORY-DATA-ANALYSIS-LAB-/blob/main/EDA(EXPERIMENT_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/1000 Sales Records (1).csv')
df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
df.head(5)
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
df.tail(5)
# Out:
#                            Region               Country   Item Type  \
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 995       Offline              C  4/18/2010  534085166  4/25/2010        6524
# 996       Offline              H   8/1/2011  590768182   9/7/2011         288
# 997        Online              C  5/12/2011  524363124  6/28/2011        9556
# 998       Offline              L  1/25/2016  289606320  2/14/2016        9801
# 999       Offline              C  4/10/2014  811546599   5/8/2014        3528
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.sample(5)

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.columns

# %%
df.dtypes

# %%
df.info()

# %%
df.describe()

# %%
df['Region'].nunique()
# Out:
# 7

# %%
df['Items Type'].value_counts()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.dropna()

# %%
df.dropna(subset=['Units Sold'])
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
df['Region'].unique()
# Out:
# array(['Middle East and North Africa', 'North America', 'Asia',
#        'Sub-Saharan Africa', 'Europe',
#        'Central America and the Caribbean', 'Australia and Oceania'],
#       dtype=object)

# %%
df['Unit Price'].fillna(df['Unit Price'].mean())

# %%
df['Item Type'].fillna(df['Item Type'].mode()[0])

# %%
df['Region'].ffill()
# Out:
# 0      Middle East and North Africa
# 1                     North America
# 2      Middle East and North Africa
# 3                              Asia
# 4                Sub-Saharan Africa
#                    ...
# 995    Middle East and North Africa
# 996                          Europe
# 997    Middle East and North Africa
# 998                          Europe
# 999                          Europe
# Name: Region, Length: 1000, dtype: object

# %%
df['Region'].bfill()

# %%
df['Total Revenue'].interpolate()

# %%
df['Unit Price'] = df['Unit Price'].fillna(df['Unit Price'].mean())
df

# %%
df.dropna(axis=1)

# %%
df.dropna(thresh=10)

# %%
df.duplicated().sum()

# %%
df[df.duplicated()]

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(subset=['Order ID'])

# %%
df.drop_duplicates(keep='last')

# %%
df.drop_duplicates(keep=False)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Order Date'].dtype

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Ship Date'].dtype

# %%
df['Units Sold'] = df['Units Sold'].astype(float)
df['Units Sold'].dtype

# %%
df['Order ID'] = df['Order ID'].astype(str)
df['Order ID'].dtype

# %%
pd.to_numeric(df['Total Profit'], errors='coerce')

# %%
df.rename(columns={'Total Revenue': 'Revenue'})

# %%
df['Profit Margin'] = df['Total Profit'] / df['Total Revenue']
df

# %%
df.drop(columns=['Profit Margin'])

# %%
df.drop(index=[0, 1])

# %%
df.insert(1, 'Country Copy', df['Country'])
df

# %%
df[df['Units Sold'] > 5000]

# %%
df[(df['Units Sold'] > 3000) & (df['Sales Channel'] == 'Online')]

# %%
df[(df['Region'] == 'Asia') | (df['Region'] == 'Europe')]

# %%
df[df['Region'].isin(['Asia', 'Europe'])]

# %%
df.query("`Units Sold` > 3000 and `Total Profit` > 100000")

# %%
df.loc[0:3, ['Country', 'Units Sold']]

# %%
df.iloc[0:3, 0:3]

# %%
df[~(df['Units Sold'] > 5000)]

# %%
df.sort_values('Total Profit', ascending=False).head(5)
python

# %%
df.sort_values(['Region', 'Total Profit'], ascending=[True, False])

# %%
df.sort_index()

# %%
df['Sales Channel'].replace('Online', 'Digital')

# %%
df['Order Priority'].map({'H': 'High', 'M': 'Medium', 'L': 'Low', 'C': 'Critical'})

# %%
np.where(df['Total Profit'] > 200000, 'High Profit', 'Low Profit')

# %%
df['Units Sold'].apply(lambda x: 'Bulk Order' if x > 5000 else 'Normal Order')

# %%
df['Country'].str.upper()

# %%
df['Country'].str.lower()

# %%
df['Country'].str.strip()

# %%
df[df['Country'].str.contains('United')]

# %%
df['Item Type'].str.replace('Cosmetics', 'Beauty')

# %%
df['Region'].str.split(' ')

# %%
df['Country'].str.len()

# %%
df['Order Year'] = df['Order Date'].dt.year
df['Order Year']

# %%
df['Order Month'] = df['Order Date'].dt.month
df['Order Month']

# %%
df['Order Day'] = df['Order Date'].dt.day
df['Order Day']

# %%
df['Order Weekday'] = df['Order Date'].dt.day_name()
df['Order Weekday']

# %%
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Shipping Days']

# %%
df.groupby('Region')['Total Profit'].mean()

# %%
df.groupby('Region').agg({'Total Profit': 'mean', 'Units Sold': 'max', 'Order ID': 'count'})

# %%
df.groupby(['Region', 'Sales Channel'])['Total Revenue'].mean()

# %%
pd.pivot_table(df, values='Total Profit', index='Region', columns='Item Type', aggfunc='mean')

# %%
df['Total Revenue'].sum()

# %%
df['Total Revenue'].mean()

# %%
df['Total Revenue'].median()

# %%
df['Total Revenue'].std()

# %%
df['Total Revenue'].var()

# %%
df['Total Revenue'].min()

# %%
df['Total Revenue'].max()

# %%
df['Order Priority'].mode()

# %%
df['Total Revenue'].agg(['sum', 'mean', 'median', 'std', 'min', 'max'])

# %%
df[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']].corr()

# %%
Q1 = df['Total Profit'].quantile(0.25)
Q3 = df['Total Profit'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df['Total Profit'] < lower) | (df['Total Profit'] > upper)]
outliers

# %%
df['Units Sold Category'] = pd.cut(df['Units Sold'], bins=[0, 2500, 5000, 7500, 10000], labels=['Low', 'Medium', 'High', 'Very High'])
df['Units Sold Category'].value_counts()

# %%
pd.qcut(df['Total Revenue'], q=4)

# %%
region_info = pd.DataFrame({
    'Region': df['Region'].unique(),
    'Manager': [f'Manager_{i}' for i in range(df['Region'].nunique())]
})
region_info

# %%
df.merge(region_info, on='Region', how='inner')

# %%
df.merge(region_info, on='Region', how='left')

# %%
df.merge(region_info, on='Region', how='right')

# %%
df.merge(region_info, on='Region', how='outer')

# %%
df_extra = df.head(5)
pd.concat([df, df_extra], ignore_index=True)

# %%
df_part1 = df[['Country', 'Region']]
df_part2 = df[['Units Sold', 'Total Revenue']]
pd.concat([df_part1, df_part2], axis=1)

# %%
df.apply(lambda row: row['Total Profit'] / row['Units Sold'], axis=1)

# %%
df[['Unit Price', 'Unit Cost']].map(lambda x: round(x, 1))

# %%
df.to_csv('sales_cleaned.csv', index=False)

# %%
df.to_excel('sales_cleaned.xlsx', index=False)

# %%
df.to_json('sales_cleaned.json', orient='records')

# %%
import matplotlib.pyplot as plt
df['Total Revenue'].hist(bins=30)
plt.show()

# %%
df['Region'].value_counts().plot(kind='bar')
plt.show()

# %%
df.boxplot(column='Total Profit', by='Region')
plt.show()

# %%
plt.scatter(df['Units Sold'], df['Total Revenue'])
plt.show()

# %%
df.groupby('Order Year')['Total Profit'].mean().plot(kind='line')
plt.show()

# %%
df['Sales Channel'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
import seaborn as sns
sns.heatmap(df[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']].corr(), annot=True)
plt.show()
